# %%
import json

with open('/home/korisnik/Desktop/Ri/archive/Batch 1/Soccer/ann/instances.json', 'r') as file:
    podaci = json.load(file)

# %%
podaci['images']
# Out:
# [{'license': 'None',
#   'file_name': 'New video.mp4_00000.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640502},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00001.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640503},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00002.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640504},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00003.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640505},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00004.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640506},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00005.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640507},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00006.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640508},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00007.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640509},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00008.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640510},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00009.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640511},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00010.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640512},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00011.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640513},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00012.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640514},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00013.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640515},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00014.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640516},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00015.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640517},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00016.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640518},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00017.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640519},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00018.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640520},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00019.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640521},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00020.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640522},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00021.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640523},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00022.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640524},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00023.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640525},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00024.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640526},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00025.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640527},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00026.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640528},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00027.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640529},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00028.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640530},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00029.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640531},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00030.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640532},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00031.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:39:59.010Z',
#   'id': 16640533},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00032.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640534},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00033.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640535},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00034.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640536},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00035.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640537},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00036.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640538},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00037.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640539},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00038.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640540},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00039.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640541},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00040.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640542},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00041.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640543},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00042.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640544},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00043.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640545},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00044.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640546},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00045.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640547},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00046.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640548},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00047.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640549},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00048.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640550},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00049.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640551},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00050.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640552},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00051.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640553},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00052.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640554},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00053.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640555},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00054.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640556},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00055.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640557},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00056.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640558},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00057.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640559},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00058.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640560},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00059.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640561},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00060.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640562},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00061.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640563},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00062.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640564},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00063.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:00.686Z',
#   'id': 16640565},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00064.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640566},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00065.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640567},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00066.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640568},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00067.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640569},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00068.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640570},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00069.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640571},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00070.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640572},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00071.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640573},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00072.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640574},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00073.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640575},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00074.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640576},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00075.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640577},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00076.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640578},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00077.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640579},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00078.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640580},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00079.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640581},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00080.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640582},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00081.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640583},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00082.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640584},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00083.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640585},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00084.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640586},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00085.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640587},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00086.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640588},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00087.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640589},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00088.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640590},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00089.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640591},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00090.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640592},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00091.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640593},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00092.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640594},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00093.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640595},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00094.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640596},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00095.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:02.260Z',
#   'id': 16640597},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00096.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640598},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00097.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640599},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00098.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640600},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00099.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640601},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00100.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640602},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00101.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640603},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00102.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640604},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00103.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640605},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00104.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640606},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00105.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640607},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00106.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640608},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00107.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640609},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00108.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640610},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00109.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640611},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00110.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640612},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00111.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640613},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00112.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640614},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00113.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640615},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00114.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640616},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00115.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640617},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00116.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640618},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00117.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640619},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00118.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640620},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00119.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640621},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00120.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640622},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00121.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640623},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00122.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640624},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00123.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640625},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00124.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640626},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00125.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640627},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00126.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640628},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00127.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:03.779Z',
#   'id': 16640629},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00128.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640630},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00129.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640631},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00130.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640632},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00131.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640633},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00132.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640634},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00133.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640635},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00134.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640636},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00135.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640637},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00136.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640638},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00137.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640639},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00138.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640640},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00139.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640641},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00140.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640642},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00141.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640643},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00142.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640644},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00143.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640645},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00144.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640646},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00145.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640647},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00146.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640648},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00147.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640649},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00148.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640650},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00149.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640651},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00150.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640652},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00151.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640653},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00152.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640654},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00153.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640655},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00154.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640656},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00155.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640657},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00156.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640658},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00157.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640659},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00158.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640660},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00159.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:05.276Z',
#   'id': 16640661},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00160.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640662},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00161.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640663},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00162.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640664},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00163.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640665},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00164.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640666},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00165.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640667},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00166.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640668},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00167.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640669},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00168.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640670},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00169.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640671},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00170.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640672},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00171.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640673},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00172.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640674},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00173.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640675},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00174.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640676},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00175.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640677},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00176.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640678},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00177.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640679},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00178.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640680},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00179.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640681},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00180.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640682},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00181.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640683},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00182.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640684},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00183.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640685},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00184.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640686},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00185.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640687},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00186.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640688},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00187.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640689},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00188.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640690},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00189.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640691},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00190.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640692},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00191.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:06.766Z',
#   'id': 16640693},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00192.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640694},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00193.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640695},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00194.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640696},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00195.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640697},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00196.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640698},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00197.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640699},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00198.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640700},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00199.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640701},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00200.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640702},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00201.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640703},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00202.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640704},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00203.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640705},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00204.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640706},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00205.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640707},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00206.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640708},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00207.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640709},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00208.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640710},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00209.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640711},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00210.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640712},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00211.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640713},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00212.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640714},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00213.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640715},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00214.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640716},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00215.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640717},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00216.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640718},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00217.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640719},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00218.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640720},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00219.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640721},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00220.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640722},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00221.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640723},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00222.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640724},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00223.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.328Z',
#   'id': 16640725},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00224.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.874Z',
#   'id': 16640726},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00225.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.874Z',
#   'id': 16640727},
#  {'license': 'None',
#   'file_name': 'New video.mp4_00226.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:40:08.874Z',
#   'id': 16640728}]

# %%
import torch
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os

class CustomDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform
        self.images = os.listdir(image_dir)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = os.path.join(self.image_dir, self.images[idx])
        mask_name = os.path.join(self.mask_dir, self.images[idx].replace('.jpg', '.png'))
        image = Image.open(img_name).convert("RGB")
        mask = Image.open(mask_name)

        if self.transform:
            image = self.transform(image)
            mask = self.transform(mask)
        
        return image, mask

transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
])

train_dataset = CustomDataset("path_to_train_images", "path_to_train_masks", transform)
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, num_workers=4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 34
#      27         return image, mask
#      29 transform = transforms.Compose([
#      30     transforms.Resize((256, 256)),
#      31     transforms.ToTensor(),
#      32 ])
# ---> 34 train_dataset = CustomDataset("path_to_train_images", "path_to_train_masks", transform)
#      35 train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, num_workers=4)
#
# Cell In[1], line 12, in CustomDataset.__init__(self, image_dir, mask_dir, transform)
#      10 self.mask_dir = mask_dir
#      11 self.transform = transform
# ---> 12 self.images = os.listdir(image_dir)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path_to_train_images'

# %%
from torchvision import models
import torch.nn as nn

class Backbone(nn.Module):
    def __init__(self):
        super(Backbone, self).__init__()
        self.backbone = models.resnet50(pretrained=True)
        self.backbone = nn.Sequential(*list(self.backbone.children())[:-2])
    
    def forward(self, x):
        x = self.backbone(x)
        return x

backbone = Backbone()
# Out:
# /home/korisnik/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/korisnik/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /home/korisnik/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████████████████████████████████| 97.8M/97.8M [00:37<00:00, 2.71MB/s]

# %%
class SemanticSegmentationHead(nn.Module):
    def __init__(self, num_classes):
        super(SemanticSegmentationHead, self).__init__()
        self.conv1 = nn.Conv2d(2048, 512, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(512)
        self.conv2 = nn.Conv2d(512, num_classes, kernel_size=1)

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = nn.ReLU()(x)
        x = self.conv2(x)
        x = nn.Upsample(scale_factor=4, mode='bilinear', align_corners=True)(x)
        return x

semantic_head = SemanticSegmentationHead(num_classes=21)  # Broj klasa u semantičkoj segmentaciji

# %%
class InstanceSegmentationHead(nn.Module):
    def __init__(self):
        super(InstanceSegmentationHead, self).__init__()
        self.conv1 = nn.Conv2d(2048, 256, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(256)
        self.conv2 = nn.Conv2d(256, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 1, kernel_size=1)

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = nn.ReLU()(x)
        x = self.conv2(x)
        x = self.bn2(x)
        x = nn.ReLU()(x)
        x = self.conv3(x)
        x = nn.Upsample(scale_factor=4, mode='bilinear', align_corners=True)(x)
        return x

instance_head = InstanceSegmentationHead()

# %%
class PanopticSegmentationModel(nn.Module):
    def __init__(self, backbone, semantic_head, instance_head):
        super(PanopticSegmentationModel, self).__init__()
        self.backbone = backbone
        self.semantic_head = semantic_head
        self.instance_head = instance_head

    def forward(self, x):
        features = self.backbone(x)
        semantic_output = self.semantic_head(features)
        instance_output = self.instance_head(features)
        return semantic_output, instance_output

model = PanopticSegmentationModel(backbone, semantic_head, instance_head).to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

def train_model(model, dataloader, criterion, optimizer, num_epochs=25):
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for inputs, masks in dataloader:
            inputs = inputs.to(device)
            masks = masks.to(device)
            
            optimizer.zero_grad()

            semantic_outputs, instance_outputs = model(inputs)
            semantic_loss = criterion(semantic_outputs, masks)
            instance_loss = criterion(instance_outputs, masks)
            loss = semantic_loss + instance_loss
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)

        epoch_loss = running_loss / len(dataloader.dataset)
        print(f'Epoch {epoch}/{num_epochs - 1}, Loss: {epoch_loss:.4f}')

    return model

model = train_model(model, train_loader, criterion, optimizer, num_epochs=25)

# %%
import json

with open('/Users/kriskasira/Documents/RiProject/archive/Batch 3/import-videos/ann/instances.json', 'r') as file:
    podaci = json.load(file)

# %%
podaci['images']
# Out:
# [{'license': 'None',
#   'file_name': 'Football batch 3.mp4_00000.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640924},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00001.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640925},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00002.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640926},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00003.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640927},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00004.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640928},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00005.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640929},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00006.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640930},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00007.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640931},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00008.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640932},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00009.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640933},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00010.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640934},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00011.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640935},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00012.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640936},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00013.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640937},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00014.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640938},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00015.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640939},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00016.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640940},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00017.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640941},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00018.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640942},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00019.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640943},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00020.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640944},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00021.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640945},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00022.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640946},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00023.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640947},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00024.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640948},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00025.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640949},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00026.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640950},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00027.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640951},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00028.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640952},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00029.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640953},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00030.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640954},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00031.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:47.612Z',
#   'id': 16640955},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00032.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640956},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00033.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640957},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00034.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640958},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00035.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640959},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00036.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640960},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00037.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640961},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00038.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640962},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00039.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640963},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00040.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640964},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00041.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640965},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00042.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640966},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00043.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640967},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00044.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640968},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00045.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640969},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00046.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640970},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00047.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640971},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00048.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640972},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00049.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640973},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00050.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640974},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00051.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640975},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00052.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640976},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00053.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640977},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00054.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640978},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00055.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640979},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00056.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640980},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00057.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640981},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00058.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640982},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00059.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640983},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00060.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640984},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00061.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640985},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00062.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640986},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00063.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:43:54.972Z',
#   'id': 16640987},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00064.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16640988},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00065.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16640989},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00066.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16640990},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00067.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16640991},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00068.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16640992},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00069.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16640993},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00070.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16640994},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00071.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16640995},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00072.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16640996},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00073.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16640997},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00074.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16640998},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00075.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16640999},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00076.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641000},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00077.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641001},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00078.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641002},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00079.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641003},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00080.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641004},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00081.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641005},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00082.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641006},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00083.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641007},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00084.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641008},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00085.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641009},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00086.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641010},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00087.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641011},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00088.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641012},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00089.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641013},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00090.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641014},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00091.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641015},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00092.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641016},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00093.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641017},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00094.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641018},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00095.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:02.695Z',
#   'id': 16641019},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00096.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641020},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00097.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641021},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00098.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641022},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00099.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641023},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00100.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641024},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00101.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641025},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00102.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641026},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00103.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641027},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00104.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641028},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00105.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641029},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00106.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641030},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00107.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641031},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00108.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641032},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00109.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641033},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00110.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641034},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00111.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641035},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00112.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641036},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00113.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641037},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00114.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641038},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00115.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641039},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00116.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641040},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00117.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641041},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00118.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641042},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00119.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641043},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00120.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641044},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00121.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641045},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00122.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641046},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00123.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641047},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00124.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641048},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00125.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641049},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00126.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641050},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00127.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:09.879Z',
#   'id': 16641051},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00128.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641052},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00129.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641053},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00130.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641054},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00131.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641055},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00132.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641056},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00133.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641057},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00134.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641058},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00135.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641059},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00136.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641060},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00137.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641061},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00138.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641062},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00139.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641063},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00140.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641064},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00141.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641065},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00142.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641066},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00143.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641067},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00144.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641068},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00145.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641069},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00146.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641070},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00147.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641071},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00148.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641072},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00149.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641073},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00150.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641074},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00151.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641075},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00152.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641076},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00153.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641077},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00154.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641078},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00155.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641079},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00156.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641080},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00157.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641081},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00158.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641082},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00159.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:16.879Z',
#   'id': 16641083},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00160.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641084},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00161.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641085},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00162.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641086},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00163.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641087},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00164.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641088},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00165.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641089},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00166.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641090},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00167.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641091},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00168.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641092},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00169.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641093},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00170.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641094},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00171.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641095},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00172.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641096},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00173.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641097},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00174.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641098},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00175.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641099},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00176.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641100},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00177.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641101},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00178.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641102},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00179.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641103},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00180.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641104},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00181.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641105},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00182.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641106},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00183.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641107},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00184.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641108},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00185.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641109},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00186.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641110},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00187.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641111},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00188.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641112},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00189.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641113},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00190.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641114},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00191.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:22.341Z',
#   'id': 16641115},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00192.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641116},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00193.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641117},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00194.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641118},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00195.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641119},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00196.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641120},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00197.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641121},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00198.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641122},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00199.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641123},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00200.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641124},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00201.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641125},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00202.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641126},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00203.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641127},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00204.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641128},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00205.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641129},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00206.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641130},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00207.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641131},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00208.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641132},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00209.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641133},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00210.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641134},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00211.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641135},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00212.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641136},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00213.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641137},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00214.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641138},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00215.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641139},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00216.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641140},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00217.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641141},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00218.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641142},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00219.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641143},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00220.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641144},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00221.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641145},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00222.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641146},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00223.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:28.356Z',
#   'id': 16641147},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00224.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641148},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00225.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641149},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00226.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641150},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00227.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641151},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00228.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641152},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00229.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641153},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00230.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641154},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00231.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641155},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00232.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641156},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00233.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641157},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00234.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641158},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00235.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641159},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00236.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641160},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00237.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641161},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00238.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641162},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00239.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641163},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00240.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641164},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00241.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641165},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00242.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641166},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00243.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641167},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00244.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641168},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00245.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641169},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00246.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641170},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00247.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641171},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00248.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641172},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00249.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641173},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00250.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641174},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00251.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641175},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00252.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641176},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00253.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641177},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00254.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:33.289Z',
#   'id': 16641178},
#  {'license': 'None',
# ...
#   'id': 16641263},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00340.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:52.101Z',
#   'id': 16641264},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00341.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:52.101Z',
#   'id': 16641265},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00342.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:52.101Z',
#   'id': 16641266},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00343.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:52.101Z',
#   'id': 16641267},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00344.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:52.101Z',
#   'id': 16641268},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00345.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:52.101Z',
#   'id': 16641269},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00346.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:52.101Z',
#   'id': 16641270},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00347.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:52.101Z',
#   'id': 16641271},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00348.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:52.101Z',
#   'id': 16641272},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00349.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:52.101Z',
#   'id': 16641273},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00350.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:52.101Z',
#   'id': 16641274},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00351.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:52.101Z',
#   'id': 16641275},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00352.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641276},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00353.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641277},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00354.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641278},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00355.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641279},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00356.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641280},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00357.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641281},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00358.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641282},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00359.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641283},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00360.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641284},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00361.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641285},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00362.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641286},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00363.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641287},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00364.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641288},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00365.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641289},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00366.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641290},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00367.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641291},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00368.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641292},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00369.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641293},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00370.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641294},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00371.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641295},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00372.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641296},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00373.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641297},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00374.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641298},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00375.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641299},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00376.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641300},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00377.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641301},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00378.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641302},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00379.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641303},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00380.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641304},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00381.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641305},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00382.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641306},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00383.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:44:58.869Z',
#   'id': 16641307},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00384.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641308},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00385.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641309},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00386.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641310},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00387.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641311},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00388.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641312},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00389.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641313},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00390.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641314},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00391.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641315},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00392.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641316},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00393.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641317},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00394.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641318},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00395.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641319},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00396.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641320},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00397.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641321},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00398.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641322},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00399.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641323},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00400.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641324},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00401.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641325},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00402.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641326},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00403.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641327},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00404.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641328},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00405.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641329},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00406.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641330},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00407.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641331},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00408.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641332},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00409.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641333},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00410.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641334},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00411.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641335},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00412.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641336},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00413.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641337},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00414.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641338},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00415.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:05.048Z',
#   'id': 16641339},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00416.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:06.590Z',
#   'id': 16641340},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00417.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:06.590Z',
#   'id': 16641341},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00418.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:06.590Z',
#   'id': 16641342},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00419.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:06.590Z',
#   'id': 16641343},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00420.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:06.590Z',
#   'id': 16641344},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00421.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:06.590Z',
#   'id': 16641345},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00422.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:06.590Z',
#   'id': 16641346},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00423.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:06.590Z',
#   'id': 16641347},
#  {'license': 'None',
#   'file_name': 'Football batch 3.mp4_00424.jpg',
#   'url': 'None',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2023-04-15T08:45:06.590Z',
#   'id': 16641348}]

# %%
import torch
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os

class CustomDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform
        self.images = os.listdir(image_dir)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_name = os.path.join(self.image_dir, self.images[idx])
        mask_name = os.path.join(self.mask_dir, self.images[idx].replace('.jpg', '.png'))
        image = Image.open(img_name).convert("RGB")
        mask = Image.open(mask_name)

        if self.transform:
            image = self.transform(image)
            mask = self.transform(mask)
        
        return image, mask

transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
])

train_dataset = CustomDataset("path_to_train_images", "path_to_train_masks", transform)
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, num_workers=4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 34
#      27         return image, mask
#      29 transform = transforms.Compose([
#      30     transforms.Resize((256, 256)),
#      31     transforms.ToTensor(),
#      32 ])
# ---> 34 train_dataset = CustomDataset("path_to_train_images", "path_to_train_masks", transform)
#      35 train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, num_workers=4)
#
# Cell In[1], line 12, in CustomDataset.__init__(self, image_dir, mask_dir, transform)
#      10 self.mask_dir = mask_dir
#      11 self.transform = transform
# ---> 12 self.images = os.listdir(image_dir)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path_to_train_images'

# %%
from torchvision import models
import torch.nn as nn

class Backbone(nn.Module):
    def __init__(self):
        super(Backbone, self).__init__()
        self.backbone = models.resnet50(pretrained=True)
        self.backbone = nn.Sequential(*list(self.backbone.children())[:-2])
    
    def forward(self, x):
        x = self.backbone(x)
        return x

backbone = Backbone()
# Out:
# /home/korisnik/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/korisnik/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /home/korisnik/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████████████████████████████████| 97.8M/97.8M [00:37<00:00, 2.71MB/s]

# %%
class SemanticSegmentationHead(nn.Module):
    def __init__(self, num_classes):
        super(SemanticSegmentationHead, self).__init__()
        self.conv1 = nn.Conv2d(2048, 512, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(512)
        self.conv2 = nn.Conv2d(512, num_classes, kernel_size=1)

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = nn.ReLU()(x)
        x = self.conv2(x)
        x = nn.Upsample(scale_factor=4, mode='bilinear', align_corners=True)(x)
        return x

semantic_head = SemanticSegmentationHead(num_classes=21)  # Broj klasa u semantičkoj segmentaciji

# %%
class InstanceSegmentationHead(nn.Module):
    def __init__(self):
        super(InstanceSegmentationHead, self).__init__()
        self.conv1 = nn.Conv2d(2048, 256, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(256)
        self.conv2 = nn.Conv2d(256, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 1, kernel_size=1)

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = nn.ReLU()(x)
        x = self.conv2(x)
        x = self.bn2(x)
        x = nn.ReLU()(x)
        x = self.conv3(x)
        x = nn.Upsample(scale_factor=4, mode='bilinear', align_corners=True)(x)
        return x

instance_head = InstanceSegmentationHead()

# %%
class PanopticSegmentationModel(nn.Module):
    def __init__(self, backbone, semantic_head, instance_head):
        super(PanopticSegmentationModel, self).__init__()
        self.backbone = backbone
        self.semantic_head = semantic_head
        self.instance_head = instance_head

    def forward(self, x):
        features = self.backbone(x)
        semantic_output = self.semantic_head(features)
        instance_output = self.instance_head(features)
        return semantic_output, instance_output

model = PanopticSegmentationModel(backbone, semantic_head, instance_head).to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

def train_model(model, dataloader, criterion, optimizer, num_epochs=25):
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for inputs, masks in dataloader:
            inputs = inputs.to(device)
            masks = masks.to(device)
            
            optimizer.zero_grad()

            semantic_outputs, instance_outputs = model(inputs)
            semantic_loss = criterion(semantic_outputs, masks)
            instance_loss = criterion(instance_outputs, masks)
            loss = semantic_loss + instance_loss
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)

        epoch_loss = running_loss / len(dataloader.dataset)
        print(f'Epoch {epoch}/{num_epochs - 1}, Loss: {epoch_loss:.4f}')

    return model

model = train_model(model, train_loader, criterion, optimizer, num_epochs=25)
